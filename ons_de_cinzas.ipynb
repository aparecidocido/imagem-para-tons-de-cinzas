# %% [markdown]
# <a href="https://colab.research.google.com/github/aparecidocido/imagem-para-tons-de-cinzas/blob/main/ons_de_cinzas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

#
caminho_imagem = "/content/imagem para cinzas/coelho 1.jpg"

#
img = cv2.imread(caminho_imagem)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#
suave = cv2.GaussianBlur(img, (7, 7), 0)

#
(T, bin) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY)
(T, binI) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY_INV)

#
resultado = np.vstack([
    np.hstack([suave, bin]),
    np.hstack([binI, cv2.bitwise_and(img, img, mask=binI)])
])

#
cv2_imshow(resultado)

#
cv2.imwrite("saida.jpg", resultado)
# Out:
# <PIL.Image.Image image mode=L size=482x402>
# True
